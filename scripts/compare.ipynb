# %%
import tensorflow as tf 
import keras 
import numpy as np
import pandas as pd 
import os
import keras.backend.tensorflow_backend as KTF

# %%
from PIL import Image
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True 
sess = tf.Session(config=config)
KTF.set_session(sess)

# %%
if KTF.image_data_format() == 'channels_last':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3

# %%
X_train=np.load(os.path.join("dataset","trainX.npy"))
X_test=np.load(os.path.join("dataset","testX.npy"))
Y_train=np.load(os.path.join("dataset","trainY.npy"))
Y_test=np.load(os.path.join("dataset","testY.npy"))


X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

Y_train = np_utils.to_categorical(Y_train, nb_classes)
Y_test = np_utils.to_categorical(Y_test, nb_classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-003a9a81d6c0> in <module>
# ----> 1 X_train=np.load(os.path.join("dataset","trainX.npy"))
#       2 X_test=np.load(os.path.join("dataset","testX.npy"))
#       3 Y_train=np.load(os.path.join("dataset","trainY.npy"))
#       4 Y_test=np.load(os.path.join("dataset","testY.npy"))
#       5
#
# ~\scoop\apps\python\current\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset\\trainX.npy'

# %%
X_max = tf.argmax(X_train,axis = CHANNEL_AXIS)

# %%
for i in range X_max.shape()[0]:
    for j in range X_
